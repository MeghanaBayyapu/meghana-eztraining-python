# %%
q1 = """In which ocean ‘Bermuda Triangle’ region is located?
a. Atlantic
b. Indian
c. Pacific
d. Arctic"""

q2 = """Which country is also known as the ‘Land of Rising Sun’?
a.Japan
b.New Zealand
c.Fiji
d.China"""

q3 = """Which one is the biggest island in the World?
a. Borneo
b. Finland
c. Sumatra
d. Greenland"""

q4 = """Which one is the largest tropical rain forest in the world?
a.Amazon
b.Bosawas
c.Southeast Asian Rain Forest
d.Daintree Rain Forest"""

q5 = """Which one is the longest continental mountain range in the world?
a. Himalaya
b. Andes
c. Rocky Mountains
d. Ural Mountains"""

questions = {q1:'a',q2:'a',q3:'d',q4:'a',q5:'b'}
name = input("Hello, what's your name?")
print("Hi",name,"Welcome to the Quiz!!")
score = 0 
for i in questions:
    print(" ")
    print(i)
    flag = input("Do you want to Skip the Question! (yes/no): ")
    if flag == "yes":
        continue
    ans = input("enter your answer: ")
    if ans == questions[i]:
        print("Wow!!, you got it correct")
        score = score+1 
        print("your current score is: ",score)
    else:
        print("Wrong answer, you lost 1 point")
        score = score-1
        print("your current score is: ",score)
    flag1 = input("Do u want to Quit? (yes/no) ")
    if flag1 == "yes":
        break
print("your final score: ",score)
# Out:
# Hello, what's your name?Meghana
# Hi Meghana Welcome to the Quiz!!
#
# In which ocean ‘Bermuda Triangle’ region is located?
# a. Atlantic
# b. Indian
# c. Pacific
# d. Arctic
# Do you want to Skip the Question! (yes/no): no
# enter your answer: a
# Wow!!, you got it correct
# your current score is:  1
# Do u want to Quit? (yes/no) no
#
# Which country is also known as the ‘Land of Rising Sun’?
# a.Japan
# b.New Zealand
# c.Fiji
# d.China
# Do you want to Skip the Question! (yes/no): no
# enter your answer: a
# Wow!!, you got it correct
# your current score is:  2
# Do u want to Quit? (yes/no) no
#
# Which one is the biggest island in the World?
# a. Borneo
# b. Finland
# c. Sumatra
# d. Greenland
# Do you want to Skip the Question! (yes/no): no
# enter your answer: c
# Wrong answer, you lost 1 point
# your current score is:  1
# Do u want to Quit? (yes/no) no
#
# Which one is the largest tropical rain forest in the world?
# a.Amazon
# b.Bosawas
# c.Southeast Asian Rain Forest
# ...
